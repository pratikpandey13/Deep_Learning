# %% [markdown]
# <a href="https://colab.research.google.com/github/pratikpandey13/Deep_Learning/blob/master/PracticeStatistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import statistics
import seaborn as sns
import matplotlib.pyplot as plt

# %%
datafream= sns.load_dataset("tips")
(np.mean(datafream["total_bill"]))
(np.median(datafream["total_bill"]))
statistics.mode(datafream["total_bill"])
# Out:
# 13.42

# %%
datafream.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(datafream["total_bill"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.histplot(datafream["total_bill"],kde=True)

# %%
q1=np.percentile(datafream["total_bill"],[25])
q3=np.percentile(datafream["total_bill"],[75])
iqr=q3-q1
lowerfence=q1-1.5*iqr
upperfence=q3+1.5*iqr
